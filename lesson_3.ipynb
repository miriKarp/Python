# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('cities.csv')

# %%
df
# Out:
#      LatD   "LatM"  LatS    NS   LonD   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"   80.0     39.0      0.0   "W"
# 1      42       52    48   "N"   97.0     23.0     23.0   "W"
# 2      46       35    59   "N"  120.0     30.0     36.0   "W"
# 3      42       16    12   "N"    NaN     48.0      NaN   "W"
# 4      43       37    48   "N"   89.0     46.0     11.0   "W"
# ..    ...      ...   ...   ...    ...      ...      ...   ...
# 123    39       31    12   "N"  119.0     48.0      NaN   "W"
# 124    50       25    11   "N"    NaN     39.0      NaN   "W"
# 125    40       10    48   "N"  122.0     14.0     23.0   "W"
# 126    40       19    48   "N"   75.0     55.0     48.0   "W"
# 127    41        9    35   "N"   81.0     14.0     23.0   "W"
#
#                    City  State
# 0          "Youngstown"     OH
# 1             "Yankton"     SD
# 2              "Yakima"     WA
# 3           "Worcester"     MA
# 4     "Wisconsin Dells"     WI
# ...

# %%
df.isnull().sum().sum()
# Out:
# 36

# %%
df.isnull().sum()
# Out:
# LatD        0
#  "LatM"     0
# LatS        0
# NS          0
# LonD       11
#  LonM""     9
#  "LonS"    16
#  EW         0
# City        0
#  State      0
# dtype: int64

# %%
df.NS = df.NS.fillna("empty")
duplicate_rows = df.duplicated()
print(duplicate_rows)
df
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 123    False
# 124    False
# 125    False
# 126    False
# 127    False
# Length: 128, dtype: bool
#      LatD   "LatM"  LatS    NS   LonD   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"   80.0     39.0      0.0   "W"
# 1      42       52    48   "N"   97.0     23.0     23.0   "W"
# 2      46       35    59   "N"  120.0     30.0     36.0   "W"
# 3      42       16    12   "N"  empty     48.0      NaN   "W"
# 4      43       37    48   "N"   89.0     46.0     11.0   "W"
# ..    ...      ...   ...   ...    ...      ...      ...   ...
# 123    39       31    12   "N"  119.0     48.0      NaN   "W"
# 124    50       25    11   "N"  empty     39.0      NaN   "W"
# 125    40       10    48   "N"  122.0     14.0     23.0   "W"
# 126    40       19    48   "N"   75.0     55.0     48.0   "W"
# 127    41        9    35   "N"   81.0     14.0     23.0   "W"
#
#                    City  State
# ...

# %%
df['LatD'].mean()
# Out:
# 38.8203125

# %%
average_population_by_country = df.groupby(" State")["LatS"].mean()
average_population_by_country
# Out:
#  State
# AL     23.000000
# AZ     12.000000
# BC     12.000000
# CA     28.333333
# CO     23.000000
# CT     59.000000
# DC     23.000000
# DE      0.000000
# FL     11.600000
# GA     41.250000
# IA     12.000000
# ID     36.000000
# IL     35.666667
# IN     39.000000
# KS     35.333333
# LA     35.000000
# MA     35.500000
# MB     48.000000
# MD     11.000000
# MI     41.500000
# MN      7.666667
# MO     17.500000
# MS     47.000000
# NB     11.000000
# NC     35.333333
# ND      5.500000
# NJ     47.000000
# NM     24.000000
# NV     12.000000
# NY     37.600000
# OH     21.200000
# OH     35.000000
# OK     41.000000
# ON      0.000000
# OR     23.000000
# PA     27.666667
# SA     11.000000
# SC     11.000000
# SD     24.000000
# TX     33.875000
# UT     23.500000
# VA     14.750000
# VT     23.500000
# WA     29.166667
# WI     29.500000
# WV     29.500000
# WY     41.500000
# Name: LatS, dtype: float64

# %%
largest_city = df.loc[df['LatS'].idxmax()]
largest_city
# Out:
# LatD                  41
#  "LatM"                5
# LatS                  59
# NS                   "N"
# LonD                80.0
#  LonM""             39.0
#  "LonS"              0.0
#  EW                  "W"
# City        "Youngstown"
#  State                OH
# Name: 0, dtype: object

# %%
smallest_city = df.loc[df['LatS'].idxmin()]
smallest_city
# Out:
# LatD                  39
#  "LatM"               45
# LatS                   0
# NS                   "N"
# LonD                75.0
#  LonM""             33.0
#  "LonS"              0.0
#  EW                  "W"
# City        "Wilmington"
#  State                DE
# Name: 9, dtype: object

# %%
df['Ratio'] = (df["LatS"]/df["LatD"])
df
# Out:
#      LatD   "LatM"  LatS    NS   LonD   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"   80.0     39.0      0.0   "W"
# 1      42       52    48   "N"   97.0     23.0     23.0   "W"
# 2      46       35    59   "N"  120.0     30.0     36.0   "W"
# 3      42       16    12   "N"    NaN     48.0      NaN   "W"
# 4      43       37    48   "N"   89.0     46.0     11.0   "W"
# ..    ...      ...   ...   ...    ...      ...      ...   ...
# 123    39       31    12   "N"  119.0     48.0      NaN   "W"
# 124    50       25    11   "N"    NaN     39.0      NaN   "W"
# 125    40       10    48   "N"  122.0     14.0     23.0   "W"
# 126    40       19    48   "N"   75.0     55.0     48.0   "W"
# 127    41        9    35   "N"   81.0     14.0     23.0   "W"
#
#                    City  State     Ratio
# 0          "Youngstown"     OH  1.439024
# 1             "Yankton"     SD  1.142857
# 2              "Yakima"     WA  1.282609
# 3           "Worcester"     MA  0.285714
# ...

# %%
df.rename(columns={'LonD': 'Population'}, inplace=True)
df
# Out:
#      LatD   "LatM"  LatS    NS  Population   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"        80.0     39.0      0.0   "W"
# 1      42       52    48   "N"        97.0     23.0     23.0   "W"
# 2      46       35    59   "N"       120.0     30.0     36.0   "W"
# 3      42       16    12   "N"         NaN     48.0      NaN   "W"
# 4      43       37    48   "N"        89.0     46.0     11.0   "W"
# ..    ...      ...   ...   ...         ...      ...      ...   ...
# 123    39       31    12   "N"       119.0     48.0      NaN   "W"
# 124    50       25    11   "N"         NaN     39.0      NaN   "W"
# 125    40       10    48   "N"       122.0     14.0     23.0   "W"
# 126    40       19    48   "N"        75.0     55.0     48.0   "W"
# 127    41        9    35   "N"        81.0     14.0     23.0   "W"
#
#                    City  State     Ratio
# 0          "Youngstown"     OH  1.439024
# 1             "Yankton"     SD  1.142857
# ...

# %%
filtered_data = df[df[' State'] == "OH"]
filtered_data
# Out:
# Empty DataFrame
# Columns: [LatD,  "LatM", LatS, NS, Population,  LonM"",  "LonS",  EW, City,  State, Ratio]
# Index: []

# %%
sorted_data = df.sort_values(by='Population', ascending=False)
sorted_data
# Out:
#      LatD   "LatM"  LatS    NS  Population   LonM""   "LonS"    EW  \
# 101    44       56    23   "N"       123.0      1.0     47.0   "W"
# 33     49       16    12   "N"       123.0      7.0     12.0   "W"
# 54     47       14    24   "N"       122.0     25.0     48.0   "W"
# 78     47       35    59   "N"       122.0     19.0      NaN   "W"
# 18     41       25    11   "N"       122.0     23.0     23.0   "W"
# ..    ...      ...   ...   ...         ...      ...      ...   ...
# 86     35       40    48   "N"         NaN     56.0     59.0   "W"
# 102    44       57     0   "N"         NaN      5.0     59.0   "W"
# 110    38       35    24   "N"         NaN     29.0      NaN   "W"
# 119    37       32    24   "N"         NaN      NaN     59.0   "W"
# 124    50       25    11   "N"         NaN     39.0      NaN   "W"
#
#               City  State     Ratio
# 101        "Salem"     OR  0.522727
# 33     "Vancouver"     BC  0.244898
# 54        "Tacoma"     WA  0.510638
# ...

# %%
df.to_csv('citiesSortedAndFiltered.csv', index=False)
